# %% [markdown]
# # Atividade Aberta 03
#
# <p style="text-align:right;">Aluno: Marcos Alves Oliveira</p>

# %% [markdown]
# ## Exercicio 01

# %% [markdown]
# Qual o valor da variável ‘resultado’ após a execução do código? Explique sua resposta.

# %%
#Exercicio 1
tupla = (3,5,7,9)
resultado = tupla[1] + tupla[-1]
print(resultado)
# Out:
# 14

# %% [markdown]
# ## Exercicio 02

# %% [markdown]
# Dado o codigo a seguir:

# %%
#Exercicio 2 
lista = [2,4,6,8,10]
lista.append(12)
lista.insert(2,5)
del lista[4]

# %% [markdown]
# Qual será o conteúdo da lista após a execução do código? Descreva as alterações
# feitas em cada passo.

# %%
print(lista)
# Out:
# [2, 4, 5, 6, 10, 12]

# %% [markdown]
# ## Exercicio 03

# %% [markdown]
# Qual será o estado final do dicionário após a execução do código? Explique como os
# valores foram alterados ou adicionados.

# %%
#Exercicio 3
dicionario = {'a':1,'b':2,'c':3}
dicionario['b'] = dicionario['c'] + 2
dicionario['d'] = 4

# %%
print(dicionario)
# Out:
# {'a': 1, 'b': 5, 'c': 3, 'd': 4}

# %% [markdown]
# ## Exercicio 04

# %% [markdown]
# Qual será o conteúdo da lista resultado após a execução do loop, e qual será o
# valor da variável resultado_final? Explique como o código funciona.

# %%
#Exercicio 4
numeros = [1,2,3,4,5,6]
resultado = []


for i in range(len(numeros)):
    if i % 2 == 0:
        resultado.append(numeros[i] ** 2)
    else:
        resultado.append(numeros[i] * 2)
print(resultado)
resultado_final = sum(resultado)
print(resultado_final)
# Out:
# [1, 4, 9, 8, 25, 12]
# 59
